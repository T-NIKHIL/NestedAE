# %%
import pandas as pd

dataset = pd.read_csv('synthetic_data_gridSamples_200_sumf5.csv', skiprows=1, header=None)

print(dataset)
# Out:
#             0          1          2          3          4          5   \
# 0     0.500000   0.500000   0.500000   0.500000   0.500000   0.500000
# 1     0.547739   0.547739   0.547739   0.547739   0.547739   0.547739
# 2     0.595477   0.595477   0.595477   0.595477   0.595477   0.595477
# 3     0.643216   0.643216   0.643216   0.643216   0.643216   0.643216
# 4     0.690955   0.690955   0.690955   0.690955   0.690955   0.690955
# ..         ...        ...        ...        ...        ...        ...
# 195   9.809045   9.809045   9.809045   9.809045   9.809045   9.809045
# 196   9.856784   9.856784   9.856784   9.856784   9.856784   9.856784
# 197   9.904523   9.904523   9.904523   9.904523   9.904523   9.904523
# 198   9.952261   9.952261   9.952261   9.952261   9.952261   9.952261
# 199  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
#
#             6          7           8           9            10          11  \
# ...
